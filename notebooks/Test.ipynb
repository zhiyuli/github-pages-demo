# %% [markdown]
# # Example Notebook
#
# **Author:** Alexander Michels

# %%
import contextily as cx
from IPython.display import display
import ipywidgets as widgets
import sys
sys.path.insert(1, "../")
import mycybergis
mycybergis.__file__
# Out:
# '/home/dijkstra/Documents/GitHubRepos/github-pages-demo/notebooks/../mycybergis/__init__.py'

# %%
from mycybergis import *

# %%
uiuc = get_uiuc_polygon()
uiuc

# %%
m = get_map_of_uiuc()
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
uiuc_gdf = get_uiuc_gdf()
uiuc_gdf
# Out:
#                                             geometry
# 0  POLYGON ((-88.20950 40.08370, -88.24690 40.083...

# %%
uiuc_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
ax = uiuc_gdf.plot()
cx.add_basemap(ax, crs=uiuc_gdf.crs.to_string())

# %%
uiuc_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
buffer_slider = widgets.FloatSlider(
    value=1000,
    min=0,
    max=10000,
    step=0.1,
    description="Buffer:"
)
display(buffer_slider)
# Out:
# FloatSlider(value=1000.0, description='Buffer:', max=10000.0)

# %%
buffer_val = buffer_slider.value
buffer_val
# Out:
# 1000.0

# %%
buff = get_uiuc_buffered_gdf(buffer=buffer_val)
buff.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
